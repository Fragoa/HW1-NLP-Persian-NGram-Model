# %%
import io 
import re

# %%
FILE_NAME = "data/train.txt"
processed_lines = []
total_word_count = 0

# %%
with io.open(FILE_NAME,'r',encoding='utf-8') as f:
    for line in f:
        line = line.strip()
        line = re.sub(r'\s+',' ',line)
        
        if not line:
            continue

        words = line.split(' ')
        word_count = len(words)
        total_word_count += word_count

        if word_count >= 3:
            processed_lines.append(line)

# %%
print(f"the count of lines : {len(processed_lines)}")
print(f"the count of words : {total_word_count}")
# Out:
# the count of lines : 188876
# the count of words : 1308765

# %%
unigram_counts = {}
bigram_counts = {}

# %%
for line in processed_lines:
    
    words = line.split(' ')

    for word in words:
        unigram_counts[word] = unigram_counts.get(word,0) + 1
    
    for i in range(len(words)-1):
        word_i = words[i]
        word_i_plus_1 = words[i+1]
        bigram = f"{word_i} {word_i_plus_1}"

        bigram_counts[bigram] = bigram_counts.get(bigram,0) + 1

# %%
print("\nUnigram Counts :")
print(dict(list(unigram_counts.items())[:5]))

print("\nBigram Counts :")
print(dict(list(bigram_counts.items())[:5]))
# Out:
# Unigram Counts :
# {'زانک': 319, 'دل': 7292, 'یا': 1553, 'اوست': 810, 'خود': 3896}
#
# Bigram Counts :
# {'زانک دل': 4, 'دل یا': 2, 'یا اوست': 1, 'اوست یا': 2, 'یا خود': 39}

# %%
list_of_unigram_counts = list(unigram_counts.items())
sorted_unigrams = sorted(list_of_unigram_counts, key=lambda item: item[1], reverse=True)

top_20_unigrams = sorted_unigrams[:20]

# %%
print("\n TOP 20 UNIGRAMS  ")
print("Rank\tWord\t\tCount\t\tRank * Count")
for i, (word, count) in enumerate(top_20_unigrams):
    rank = i + 1
    frequency = count
    rank_times_count = rank * frequency

    print(f"{rank}\t{word}\t\t{frequency}\t\t{rank_times_count}")
# Out:
#  TOP 20 UNIGRAMS
# Rank	Word		Count		Rank * Count
# 1	و		50915		50915
# 2	از		31187		62374
# 3	به		30038		90114
# 4	که		26796		107184
# 5	در		23533		117665
# 6	تو		22021		132126
# 7	را		19844		138908
# 8	ز		17404		139232
# 9	بر		14945		134505
# 10	آن		13251		132510
# 11	او		12024		132264
# 12	من		10844		130128
# 13	چون		10710		139230
# 14	ای		8789		123046
# 15	تا		8382		125730
# 16	می		8381		134096
# 17	این		8368		142256
# 18	چو		7743		139374
# 19	بود		7633		145027
# 20	دل		7292		145840

# %%
list_of_bigram_counts = list(bigram_counts.items())
sorted_bigrams = sorted(list_of_bigram_counts, key=lambda item: item[1], reverse=True)

top_20_bigrams = sorted_bigrams[:20]

# %%
print("\nTOP 20 BIGRAMS")
print("Rank\tBigram\t\t\tCount\t\tRank * Count")

for i, (bigram, count) in enumerate(top_20_bigrams):
    rank = i + 1
    frequency = count
    rank_times_count = rank * frequency
    

    print(f"{rank}\t{bigram}\t\t{frequency}\t\t{rank_times_count}")
# Out:
# TOP 20 BIGRAMS
# Rank	Bigram			Count		Rank * Count
# 1	از آن		1394		1394
# 2	که در		1247		2494
# 3	او را		1123		3369
# 4	را به		1105		4420
# 5	که از		1070		5350
# 6	است و		828		4968
# 7	که به		787		5509
# 8	از تو		779		6232
# 9	بر سر		771		6939
# 10	تا به		744		7440
# 11	ما را		729		8019
# 12	تو را		710		8520
# 13	و از		681		8853
# 14	و در		674		9436
# 15	تو در		667		10005
# 16	هر دو		644		10304
# 17	از پی		612		10404
# 18	و به		595		10710
# 19	را ز		593		11267
# 20	و آن		572		11440

# %%
def compute_freq(file_path : str, n: int):
    ngram_counts = {}

    for line in processed_lines:
        words = line.split(' ')
    
        for i in range(len(words) - n + 1):

            ngram = words[i:i + n]
            ngram_text = ' '.join(ngram)
            
            ngram_counts[ngram_text] = ngram_counts.get(ngram_text, 0) + 1
    print(f"\n Frequency of {n}-GRAM Combinations (Total Unique: {len(ngram_counts)})")
    

    sorted_ngrams = sorted(ngram_counts.items(), key=lambda item: item[1], reverse=True)
    
    for i, (ngram, count) in enumerate(sorted_ngrams[:20]):
        print(f"[{count}]\t{ngram}")

# %%
compute_freq('data/train.txt',3)
# Out:
#  Frequency of 3-GRAM Combinations (Total Unique: 825417)
# [205]	روز و شب
# [159]	جان و دل
# [155]	دل و جان
# [132]	شب و روز
# [125]	آتش و آب
# [91]	بعد از آن
# [88]	آن را که
# [87]	آن کس که
# [85]	نیک و بد
# [82]	او را به
# [78]	مر او را
# [75]	مرد و زن
# [74]	سیم و زر
# [71]	که او را
# [67]	خود را به
# [67]	زیر و زبر
# [66]	هر که را
# [65]	شرق و غرب
# [63]	من و تو
# [58]	فتح و ظفر

# %%
def calculate_bigaram_prob(word_prev,word_curr):

    bigram = f"{word_prev} {word_curr}"

    bigram_count = bigram_count.get(bigram, 0)
    unigram_count = unigram_count.get(word_prev, 0)

    if unigram_count == 0:
        return 0.0
    
    return bigram_count / unigram_count

# %%
def find_best_completions(context_word, all_words, n=2):

    potential_bigrams = {}
    
    for word_curr in all_words:
        bigram_key = f"{context_word} {word_curr}"
        

        count = bigram_counts.get(bigram_key, 0)
        
        if count > 0:
            potential_bigrams[word_curr] = count
            
    sorted_completions = sorted(potential_bigrams.items(), key=lambda item: item[1], reverse=True)
    
    return sorted_completions[:n]

# %%
VOCABULARY = list(unigram_counts.keys())

PHRASES = [
    "چون مشک سیه بود مرا هر دو بنا",
    "گر خورد سوگند هم آن",
    "زانک نفس آشفته تر گردد از",
    "از ین زشت تر در جهان رنگ"
]

# %%
for phrase_num, phrase in enumerate(PHRASES):
    print(f"\n PHRASE {phrase_num + 1}")
    
    context_word = phrase.split(' ')[-1]
    
    print(f"1: {phrase} ---")
    
   
    all_potential_counts = {}
    for word_curr in VOCABULARY:
        bigram_key = f"{context_word} {word_curr}"
        count = bigram_counts.get(bigram_key, 0) 
        if count > 0:
            all_potential_counts[word_curr] = count
    
    sorted_all_options = sorted(all_potential_counts.items(), key=lambda item: item[1], reverse=True)
    
    output_line_2 = ""
    for word, count in sorted_all_options:
        output_line_2 += f"({word}, {count}) "
    
    print(f"2: {output_line_2.strip()}")
    
    top_completions = sorted_all_options[:2]
# Out:
#  PHRASE 1
# 1: چون مشک سیه بود مرا هر دو بنا ---
# 2: (گوش, 7) (و, 5) (کرده, 4) (را, 3) (کرد, 3) (که, 2) (نهادی, 2) (نهند, 2) (از, 1) (ز, 1) (بهر, 1) (هم, 1) (نه, 1) (بر, 1) (شود, 1) (آماده, 1) (بلند, 1) (گاه, 1) (نو, 1) (بانی, 1) (فکنده, 1) (کردی, 1) (هنوز, 1) (فرخ, 1) (ایمن, 1) (چندان, 1) (کردست, 1) (خواستند, 1) (جستن, 1) (آزموده, 1) (حاکم, 1) (موضع, 1) (گوشش, 1) (نمودن, 1) (پرداخت, 1) (نعمه, 1) (لیلا, 1)
#
#  PHRASE 2
# 1: گر خورد سوگند هم آن ---
# 2: (را, 324) (که, 322) (یکی, 180) (به, 159) (کس, 126) (دو, 121) (زمان, 118) (دم, 111) (روز, 100) (زلف, 99) (دل, 89) (در, 80) (روی, 78) (بت, 74) (چنان, 70) (یک, 70) (همه, 66) (ماه, 66) (بود, 65) (لب, 63) (ز, 60) (گه, 60) (باشد, 56) (از, 55) (چشم, 54) (کو, 54) (سرو, 54) (جهان, 53) (شاه, 52) (دگر, 51) (سو, 50) (و, 46) (تو, 46) (جان, 46) (شب, 46) (سر, 45) (کز, 44) (آب, 43) (هم, 43) (می, 42) (نه, 39) (شوخ, 39) (ترک, 38) (یار, 38) (بر, 36) (کسی, 36) (رخ, 35) (مرد, 35) (مه, 35) (چه, 34) (هر, 33) (است, 33) (خانه, 33) (نگار, 33) (بی, 31) (نیست, 31) (نرگس, 31) (کار, 30) (شد, 29) (شه, 29) (خود, 28) (من, 28) (خط, 28) (رو, 26) (باده, 25) (چو, 25) (آتش, 25) (سخن, 25) (دلبر, 25) (باغ, 24) (شیر, 24) (لحظه, 24) (صنم, 24) (گل, 23) (راه, 23) (کند, 23) (آمد, 23) (ساعت, 23) (خداوندی, 23) (پس, 22) (سوی, 22) (چون, 22) (خاک, 22) (باد, 22) (لعل, 22) (قوم, 22) (گروه, 22) (سلطان, 21) (پسر, 21) (روزی, 20) (نفس, 20) (نامه, 20) (شهر, 20) (ره, 19) (ملک, 19) (جمله, 19) (بخت, 19) (زمین, 19) (دارد, 18) (دست, 18) (نبود, 18) (طره, 18) (غمزه, 18) (نور, 18) (کوه, 18) (کیست, 18) (صورت, 17) (شراب, 17) (عالم, 17) (گوهر, 17) (مست, 17) (موی, 17) (وقت, 17) (شنیدی, 17) (خویش, 16) (جا, 16) (پر, 16) (خواجه, 16) (کشور, 16) (صفت, 16) (او, 15) (شود, 15) (جای, 15) (کاو, 15) (طرف, 15) (تا, 14) (دیده, 14) (تیر, 14) (زن, 14) (خون, 14) (قدر, 14) (مرغ, 14) (گنج, 14) (چشمه, 14) (جام, 14) (دول
برگ, 1) (گرفت, 1) (زد, 1) (بین, 1) (مکن, 1) (آماده, 1) (چه, 1) (آید, 1) (باش, 1) (آفتاب, 1) (کند, 1) (جهان, 1) (وز, 1) (شقایق, 1) (نیست, 1) (گم, 1) (بینی, 1) (سما, 1) (طره, 1) (آمد, 1) (نهد, 1) (بینم, 1) (دار, 1) (خامه, 1) (صحرا, 1) (حسن, 1) (یک, 1) (نی, 1) (گوهر, 1) (داده, 1) (گردد, 1) (بازی, 1) (قیمت, 1) (شده, 1) (تنم, 1) (کنم, 1) (یافته, 1) (ده, 1) (تار, 1) (کی, 1) (غم, 1) (آموز, 1) (شوی, 1) (سیه, 1) (زمین, 1) (لب, 1) (طبیعت, 1) (آدم, 1) (سنت, 1) (آرد, 1) (خنجر, 1) (مختلف, 1) (پیر, 1) (گهر, 1) (سهیل, 1) (ساز, 1) (شاخ, 1) (گشتی, 1) (سیاه, 1) (آهن, 1) (ولیکن, 1) (پنهان, 1) (شمشیر, 1) (نگار, 1) (یکرنگست, 1) (کلاه, 1) (افتاد, 1) (باطن, 1) (نقش, 1) (شیخ, 1) (های, 1) (چشمی, 1) (نیشکر, 1) (لبش, 1) (لطیف, 1) (خاست, 1) (نپذیرد, 1) (سیمرغ, 1) (نیل, 1) (عصیان, 1) (عاجز, 1) (بخشد, 1) (تیره, 1) (هندو, 1) (عقیق, 1) (داران, 1) (اعدای, 1) (بهاری, 1) (ماشطه, 1) (رویی, 1) (مالامال, 1) (کاس, 1) (مسکن, 1) (مل, 1) (زهره, 1) (فراموش, 1) (آلود, 1) (ریخت, 1) (رعنایی, 1) (ته, 1) (ثواب, 1) (تباهی, 1) (ریزی, 1) (آوری, 1) (بناگوش, 1) (مویت, 1) (عدوی, 1) (جنباند, 1) (ظلام, 1) (دینارست, 1) (مجسم, 1) (مطلوبی, 1) (لام, 1) (لبت, 1) (رویشان, 1) (اخگر, 1) (پنداشت, 1) (ادبار, 1) (کهربا, 1) (جگرگوشه, 1) (قیر, 1) (شفق, 1) (حسام, 1) (آتشست, 1) (احسن, 1) (برآر, 1) (رویم, 1) (خنجرش, 1) (بپوشید, 1) (نابینا, 1) (آموده, 1) (کثیف, 1) (برداری, 1) (جبهه, 1) (آمیخت, 1) (زردم, 1) (زداید, 1) (رخسارم, 1) (سودست, 1) (زبرجد, 1) (رزی, 1) (آمیزی, 1) (بدیع, 1) (خضاب, 1) (پوشیدن, 1) (زشتان, 1) (مرآت, 1) (جفون, 1) (ثمار, 1) (شقاق, 1) (زاج, 1) (دلاوبز, 1) (نبودست, 1) (مظلم, 1) (زنگاری, 1) (زدیم, 1) (وزرق, 1) (کبودی, 1) (عبادات, 1) (بسام, 1) (بادرنگ, 1) (سبزیست, 1) (کلف, 1) (وکافرکیش, 1) (ناردانم, 1) (چونه, 1) (بدزدید, 1) (ازشب, 1) (آمیختن, 1) (محویست, 1) (وبوی, 1)
